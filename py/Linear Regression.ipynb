# %% [markdown]
# # Simple Linear Regression

# %%
import SimpleLinearRegression
model = SimpleLinearRegression.SimpleLinearRegression('/home/karandalvi/machine_learning/data/kc_house_data.csv','sqft_living','price')
# Out:
# Model built successfully

# %%
model.predict(2000)
# Out:
# 517666.39270042244

# %%
model.getTrainRMSE()
# Out:
# 68351286833.040047

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(model.featureData, model.outcomeData, '.',
        model.featureData, model.predict(model.featureData), '-')
